# %% [markdown]
# # Greetings

# %%
name=input("Enter your name:")
age=input("Enter your age:")
Greeting=("Good Morning, My name is  {name}. I'm {age} years old")
# Out:
# Enter your name: Light
# Enter your age: 32

# %%
Greeting
# Out:
# "Good Morning, My name is {name}. I'm {age} years old"

# %% [markdown]
# ## Area of a Rectangle

# %%
Length=float(input("enter your value:"))
width=float(input("enter your value:"))
area=Length * width
# Out:
# enter your value: 34
# enter your value: 56

# %%
area=Length * width

# %%
area
# Out:
# 1904.0

# %%
1 year=365 days
1 week=7 days
2 years=1 year * 2
2 weeks=1 week  * 2
# Out:
#   Cell In[22], line 1
#     1 year= 365 days
#       ^
# SyntaxError: invalid syntax

# %%
Score1=float(input("enter your value"))
Score2=float(input("enter your value"))
Score3=float(input("enter your value"))
Average score=Score1 + Score2 + Score3 / 3
# Out:
#   Cell In[21], line 4
#     Average score=Score1 + Score2 + Score3 / 3
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Area and Circumference of a Circle

# %%
PI=3.14159
radius=float(input("enter the value"))
circumference=2 * PI * radius
area=PI * radius ** 2
# Out:
# enter the value 23

# %%
area
# Out:
# 1661.90111

# %%
circumference
# Out:
# 144.51314

# %%
a=2
b=5
c=a+b
f=a * b
D=a-b
X=a/b
F=a ** b

# %% [markdown]
# ## Sum, Difference, Product, Qoutient and Remainders

# %%
c
# Out:
# 7

# %%
f
# Out:
# 10

# %%
X
# Out:
# 0.4

# %%
D
# Out:
# -3

# %%
F
# Out:
# 32

# %% [markdown]
# celsius=float(input("enter temperature in celsius"))
# f_output=(c_input * 9/5) + 32
#     print(f"{c_input}<sup>o</sup>C is equal to {farenheit:.2f}<sup>o</sup>F)

# %%
celsius=float(input("enter temperature in celsius"))
f_output=(c_input * 9/5) + 32                            
    print(f"{c_input}<sup>o</sup>C is equal to {farenheit:.2f}<sup>o</sup>F)
# Out:
#   Cell In[42], line 3
#     print(f"{c_input}<sup>o</sup>C is equal to {farenheit:.2f}<sup>o</sup>F)
#     ^
# IndentationError: unexpected indent

# %%
sentence=input("enter a sentence:")
len(sentence)
# Out:
# enter a sentence: My name is Light Enyichukwu
# 27

# %%
First_name=input("enter your first name:")
Last_name=input("enter your last name")
Full_name= First_name+" "+ Last_name
# Out:
# enter your first name: Enyichukwu
# enter your last name Light

# %%
Full_name
# Out:
# 'Enyichukwu Light'
